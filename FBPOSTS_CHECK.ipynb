# %%
import django
import os
os.environ["DJANGO_SETTINGS_MODULE"]="facebook.settings"

django.setup()

# %%
from fbposts.posts import get_post

# %%
from django.db import connection
for each in connection.queries:
    print(each)

# %%
get_post(1)
# Out:
# get comments sub call 0
# get comments sub call 0
# get comments sub call 0
# get comments 1
# get comments sub call 0
# get comments 0
# get comments sub call 0
# get comments sub call 0
# get comments sub call 0
# get comments 2
# get comments sub call 0
# get comments 0
# get comments 7
# complete: 16
# {'post_id': 1,
#  'posted_by': {'user_id': 1,
#   'name': 'ib_admin',
#   'profile_pic_url': 'sampe.png'},
#  'posted_at': '19-07-02 11:29:11.605058',
#  'post_content': 'my first post',
#  'reactions': {'LIKE': 3},
#  'comments': [{'comment_id': 1,
#    'commenter': {'user_id': 2,
#     'name': 'ib_cricket',
#     'profile_pic_url': 'cricket.png'},
#    'commented_at': '19-07-03 04:44:02.248951',
#    'comment_content': 'hey',
#    'reactions': {'LIKE': 1, 'LOVE': 1, 'WOW': 1},
#    'replies_count': 1,
#    'replies': [{'comment_id': 6,
#      'commenter': {'user_id': 1,
#       'name': 'ib_admin',
#       'profile_pic_url': 'sampe.png'},
#      'commented_at': '19-07-04 04:38:21.202976',
#      'comment_content': 'hi',
#      'reactions': {'LIKE': 1}}]},
#   {'comment_id': 2,
#    'commenter': {'user_id': 1,
#     'name': 'ib_admin',
#     'profile_pic_url': 'sampe.png'},
#    'commented_at': '19-07-03 05:34:49.516787',
#    'comment_content': 'ok',
#    'reactions': {},
#    'replies_count': 0,
#    'replies': []},
#   {'comment_id': 3,
#    'commenter': {'user_id': 1,
#     'name': 'ib_admin',
#     'profile_pic_url': 'sampe.png'},
#    'commented_at': '19-07-03 11:32:41.583149',
#    'comment_content': 'jupyter',
#    'reactions': {'LIKE': 1},
#    'replies_count': 2,
#    'replies': [{'comment_id': 4,
#      'commenter': {'user_id': 2,
#       'name': 'ib_cricket',
#       'profile_pic_url': 'cricket.png'},
#      'commented_at': '19-07-03 11:56:20.160971',
#      'comment_content': 'reply',
#      'reactions': {'LOVE': 1}},
#     {'comment_id': 5,
#      'commenter': {'user_id': 2,
#       'name': 'ib_cricket',
#       'profile_pic_url': 'cricket.png'},
#      'commented_at': '19-07-03 11:56:40.991983',
#      'comment_content': 'nested reply',
#      'reactions': {'WOW': 1}}]},
#   {'comment_id': 58,
#    'commenter': {'user_id': 1,
#     'name': 'ib_admin',
#     'profile_pic_url': 'sampe.png'},
#    'commented_at': '19-07-05 09:46:10.267220',
#    'comment_content': 'hi',
#    'reactions': {},
#    'replies_count': 0,
#    'replies': []}],
#  'comments_count': 4}

# %%
from fbposts.posts import create_post

# %%
create_post(2,"user2 post")
# Out:
# 39

# %%
from fbposts.comments import add_comment

# %%
add_comment(12,1,"user1 comment")
# Out:
# 56

# %%
from fbposts.comments import reply_to_comment

# %%
reply_to_comment(7,2,"user2 reply")
# Out:
# 57

# %%
from fbposts.comments import get_replies_for_comment

# %%
get_replies_for_comment(7)
# Out:
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get_post_by_object: 6
# [{'comment_id': 8,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 04:45:57.172528',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 10,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 04:59:42.779871',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 12,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 05:00:20.141424',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 14,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 05:31:52.541860',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 16,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 05:32:51.437957',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 18,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 05:35:30.264678',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 20,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 05:40:05.293487',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 22,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 05:40:47.621122',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 24,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 09:24:18.463820',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 26,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 09:26:14.291674',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 31,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 09:40:34.795750',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 33,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 09:43:33.205450',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 35,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 09:43:43.403444',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 37,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 09:43:51.542585',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 39,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 09:45:39.879333',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 41,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 09:45:56.221069',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 43,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 09:48:26.928371',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 45,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 09:53:45.558747',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 47,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 10:01:03.989926',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 49,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 10:04:59.129250',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 51,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 10:05:16.829266',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 53,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-04 10:25:22.805621',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 55,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-05 05:11:31.874629',
#   'comment_content': 'user2 reply'},
#  {'comment_id': 57,
#   'commenter': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'commented_at': '19-07-05 06:10:52.390583',
#   'comment_content': 'user2 reply'}]

# %%
from fbposts.reactions import react_to_post

# %%
react_to_post(3,12,'WOW')

# %%
from fbposts.posts import get_reactions_to_post

# %%
get_reactions_to_post(1)
# Out:
# get comments sub call 0
# get comments sub call 0
# get comments sub call 0
# complete: 1
# [{'user_id': 2,
#   'name': 'ib_cricket',
#   'profile_pic_url': 'cricket.png',
#   'reaction': 'LIKE'},
#  {'user_id': 3,
#   'name': 'cybereye',
#   'profile_pic_url': 'cyber.jpg',
#   'reaction': 'LIKE'},
#  {'user_id': 1,
#   'name': 'ib_admin',
#   'profile_pic_url': 'sampe.png',
#   'reaction': 'LIKE'}]

# %%
from fbposts.reactions import react_to_comment

# %%
react_to_comment(1,8,'WOW')

# %%
from fbposts.posts import get_user_posts

# %%
get_user_posts(1)
# Out:
# get comments sub call 0
# get post-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments 0
# get_post_by_object: 0
# get comments sub call 0
# get post-reactions 0
# get comments 0
# get_post_by_object: 0
# complete: 8
# [{'post_id': 1,
#   'posted_by': {'user_id': 1,
#    'name': 'ib_admin',
#    'profile_pic_url': 'sampe.png'},
#   'posted_at': '19-07-02 11:29:11.605058',
#   'post_content': 'my first post',
#   'reactions': {'count': 3, 'type': ['LIKE']},
#   'comments': [{'comment_id': 1,
#     'commenter': {'user_id': 2,
#      'name': 'ib_cricket',
#      'profile_pic_url': 'cricket.png'},
#     'commented_at': '19-07-03 04:44:02.248951',
#     'comment_content': 'hey',
#     'reactions': {'count': 3, 'type': ['LIKE', 'LOVE', 'WOW']},
#     'replies_count': 1,
#     'replies': [{'comment_id': 6,
#       'commenter': {'user_id': 1,
#        'name': 'ib_admin',
#        'profile_pic_url': 'sampe.png'},
#       'commented_at': '19-07-04 04:38:21.202976',
#       'comment_content': 'hi',
#       'reactions': {'count': 1, 'type': ['LIKE']}}]},
#    {'comment_id': 2,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-03 05:34:49.516787',
#     'comment_content': 'ok',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 3,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-03 11:32:41.583149',
#     'comment_content': 'jupyter',
#     'reactions': {'count': 1, 'type': ['LIKE']},
#     'replies_count': 2,
#     'replies': [{'comment_id': 4,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-03 11:56:20.160971',
#       'comment_content': 'reply',
#       'reactions': {'count': 1, 'type': ['LOVE']}},
#      {'comment_id': 5,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-03 11:56:40.991983',
#       'comment_content': 'nested reply',
#       'reactions': {'count': 1, 'type': ['WOW']}}]},
#    {'comment_id': 58,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-05 09:46:10.267220',
#     'comment_content': 'hi',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []}],
#   'comments_count': 4},
#  {'post_id': 3,
#   'posted_by': {'user_id': 1,
#    'name': 'ib_admin',
#    'profile_pic_url': 'sampe.png'},
#   'posted_at': '19-07-03 07:07:04.830039',
#   'post_content': 'through jupyter',
#   'reactions': {'count': 3, 'type': ['HAHA', 'SAD', 'ANGRY']},
#   'comments': [],
#   'comments_count': 0}]

# %%
from fbposts.posts import get_posts_with_more_positive_reactions

# %%
get_posts_with_more_positive_reactions()
# Out:
# complete: 1
# [1, 2, 12]

# %%
from fbposts.posts import get_posts_reacted_by_user

# %%
get_posts_reacted_by_user(1)
# Out:
# get comments sub call 0
# get post-reactions 0
# get comments 0
# get_post_by_object: 0
# get comments sub call 0
# get post-reactions 0
# get comments 0
# get_post_by_object: 0
# get comments sub call 0
# get post-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments 0
# get_post_by_object: 0
# get comments sub call 0
# get post-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments 0
# get_post_by_object: 0
# complete: 8
# [{'post_id': 2,
#   'posted_by': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'posted_at': '19-07-03 04:41:30.292149',
#   'post_content': 'user2 post',
#   'reactions': {'count': 2, 'type': ['HAHA', 'WOW']},
#   'comments': [],
#   'comments_count': 0},
#  {'post_id': 3,
#   'posted_by': {'user_id': 1,
#    'name': 'ib_admin',
#    'profile_pic_url': 'sampe.png'},
#   'posted_at': '19-07-03 07:07:04.830039',
#   'post_content': 'through jupyter',
#   'reactions': {'count': 3, 'type': ['HAHA', 'SAD', 'ANGRY']},
#   'comments': [],
#   'comments_count': 0},
#  {'post_id': 1,
#   'posted_by': {'user_id': 1,
#    'name': 'ib_admin',
#    'profile_pic_url': 'sampe.png'},
#   'posted_at': '19-07-02 11:29:11.605058',
#   'post_content': 'my first post',
#   'reactions': {'count': 3, 'type': ['LIKE']},
#   'comments': [{'comment_id': 1,
#     'commenter': {'user_id': 2,
#      'name': 'ib_cricket',
#      'profile_pic_url': 'cricket.png'},
#     'commented_at': '19-07-03 04:44:02.248951',
#     'comment_content': 'hey',
#     'reactions': {'count': 3, 'type': ['LIKE', 'LOVE', 'WOW']},
#     'replies_count': 1,
#     'replies': [{'comment_id': 6,
#       'commenter': {'user_id': 1,
#        'name': 'ib_admin',
#        'profile_pic_url': 'sampe.png'},
#       'commented_at': '19-07-04 04:38:21.202976',
#       'comment_content': 'hi',
#       'reactions': {'count': 1, 'type': ['LIKE']}}]},
#    {'comment_id': 2,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-03 05:34:49.516787',
#     'comment_content': 'ok',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 3,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-03 11:32:41.583149',
#     'comment_content': 'jupyter',
#     'reactions': {'count': 1, 'type': ['LIKE']},
#     'replies_count': 2,
#     'replies': [{'comment_id': 4,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-03 11:56:20.160971',
#       'comment_content': 'reply',
#       'reactions': {'count': 1, 'type': ['LOVE']}},
#      {'comment_id': 5,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-03 11:56:40.991983',
#       'comment_content': 'nested reply',
#       'reactions': {'count': 1, 'type': ['WOW']}}]},
#    {'comment_id': 58,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-05 09:46:10.267220',
#     'comment_content': 'hi',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []}],
#   'comments_count': 4},
#  {'post_id': 12,
#   'posted_by': {'user_id': 2,
#    'name': 'ib_cricket',
#    'profile_pic_url': 'cricket.png'},
#   'posted_at': '19-07-04 04:43:30.259064',
#   'post_content': 'user2 post',
#   'reactions': {'count': 1, 'type': ['LIKE']},
#   'comments': [{'comment_id': 7,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 04:44:40.626367',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 24,
#     'replies': [{'comment_id': 8,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 04:45:57.172528',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 10,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 04:59:42.779871',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 12,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 05:00:20.141424',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 14,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 05:31:52.541860',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 16,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 05:32:51.437957',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 18,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 05:35:30.264678',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 20,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 05:40:05.293487',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 22,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 05:40:47.621122',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 24,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 09:24:18.463820',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 26,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 09:26:14.291674',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 31,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 09:40:34.795750',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 33,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 09:43:33.205450',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 35,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 09:43:43.403444',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 37,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 09:43:51.542585',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 39,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 09:45:39.879333',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 41,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 09:45:56.221069',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 43,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 09:48:26.928371',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 45,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 09:53:45.558747',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 47,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 10:01:03.989926',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 49,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 10:04:59.129250',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 51,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 10:05:16.829266',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 53,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-04 10:25:22.805621',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 55,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-05 05:11:31.874629',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}},
#      {'comment_id': 57,
#       'commenter': {'user_id': 2,
#        'name': 'ib_cricket',
#        'profile_pic_url': 'cricket.png'},
#       'commented_at': '19-07-05 06:10:52.390583',
#       'comment_content': 'user2 reply',
#       'reactions': {'count': 0, 'type': []}}]},
#    {'comment_id': 9,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 04:59:42.759955',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 11,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 05:00:20.125743',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 13,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 05:31:52.518227',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 15,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 05:32:51.420833',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 17,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 05:35:30.246778',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 19,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 05:40:05.276006',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 21,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 05:40:47.603198',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 23,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 09:24:18.442664',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 25,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 09:26:14.273898',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 27,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 09:30:32.521501',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 28,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 09:35:59.763433',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 29,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 09:39:38.707877',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 30,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 09:40:34.775988',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 32,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 09:43:33.188295',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 34,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 09:43:43.381866',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 36,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 09:43:51.515181',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 38,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 09:45:39.863777',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 40,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 09:45:56.201410',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 42,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 09:48:26.909084',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 44,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 09:53:45.542751',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 46,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 10:01:03.965484',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 48,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 10:04:59.112060',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 50,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 10:05:16.807778',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 52,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-04 10:25:22.785352',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 54,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-05 05:11:31.845017',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []},
#    {'comment_id': 56,
#     'commenter': {'user_id': 1,
#      'name': 'ib_admin',
#      'profile_pic_url': 'sampe.png'},
#     'commented_at': '19-07-05 06:10:52.373213',
#     'comment_content': 'user1 comment',
#     'reactions': {'count': 0, 'type': []},
#     'replies_count': 0,
#     'replies': []}],
#   'comments_count': 27}]

# %%
from fbposts.reactions import get_reaction_metrics

# %%
get_reaction_metrics(3)
# Out:
# complete: 1
# {'ANGRY': 1, 'HAHA': 1, 'SAD': 1}

# %%
from fbposts.reactions import get_total_reaction_count

# %%
get_total_reaction_count()
# Out:
# complete: 1
# {1: 3, 2: 2, 3: 3, 12: 1}

# %%
import datetime

# %%
str(datetime.datetime.now())

# %%
from fbposts.models import Post,Comment,Reaction
from django.db.models import Prefetch
posts=Post.objects.filter(posted_by_id=1).select_related('posted_by')\
           .prefetch_related(Prefetch('reactions',queryset=Reaction.objects.all()))\
           .prefetch_related(Prefetch('comments',queryset=Comment.objects.all()))
print(posts)
for post in posts:
    print(post.comments.all())
# Out:
# <QuerySet [<Post: Post object (1)>, <Post: Post object (3)>]>
# <QuerySet [<Comment: Comment object (1)>, <Comment: Comment object (2)>, <Comment: Comment object (3)>]>
# <QuerySet []>
# <QuerySet []>

# %%
from fbposts.models import *
from django.db import connection
comments = Post.objects.get(id=1).comments.all().select_related('commenter') .prefetch_related('replies__reactions', 'reactions', 'replies__commenter','replies')

from fbposts.comments import get_comments

print(len(connection.queries))
get_comments(comments)
print(len(connection.queries))
# Out:
# 2
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments sub call 0
# get comments-reactions 0
# get comments 0
# get comments 5
# 7

# %%
from django.db.models import Count,Q
from fbposts.models import *

Reaction.objects.filter(Q(comment = None)).values('post','reaction_type').annotate(count=Count('reaction_type'))
# Out:
# <QuerySet [{'post': 1, 'reaction_type': 'LIKE', 'count': 3}, {'post': 2, 'reaction_type': 'HAHA', 'count': 1}, {'post': 2, 'reaction_type': 'WOW', 'count': 1}, {'post': 3, 'reaction_type': 'ANGRY', 'count': 1}, {'post': 3, 'reaction_type': 'HAHA', 'count': 1}, {'post': 3, 'reaction_type': 'SAD', 'count': 1}, {'post': 12, 'reaction_type': 'LIKE', 'count': 1}]>
